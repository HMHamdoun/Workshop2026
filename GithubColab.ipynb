# %% [markdown]
# <a href="https://colab.research.google.com/github/HMHamdoun/Workshop2026/blob/main/GithubColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace 'your_dataset_path.csv' with the actual path from your Google Drive
dataset_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/job_salary_prediction_dataset.csv'

try:
    df = pd.read_csv(dataset_path)
    print(df.head()) # Print the first 5 rows to verify
except FileNotFoundError:
    print(f"Error: The file was not found at {dataset_path}")
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media       Medium  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/Dataset/ant-1.3.csv"
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Dataset/ant-1.3.csv'
